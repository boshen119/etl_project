# %%
import os
import pandas as pd
import csv

# %%
sd_csv = "./1slickdeals_final.csv"
gr_csv = "./1groupon_master.csv"

# %%
sd_df = pd.read_csv(sd_csv)
gr_df = pd.read_csv(gr_csv)

# %%
# Merge Dataframes together 
all_data = sd_df.append(gr_df)
all_data
# Out:
# /Users/Bons/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
#                                                    Item Old Price  \
# 0     12oz Birch Benders Pancake & Waffle Mix (Paleo...       $48
# 1     12oz Birch Benders Pancake & Waffle Mix (Paleo...       $48
# 2     12oz Birch Benders Pancake & Waffle Mix (Paleo...       $48
# 3     12oz Birch Benders Pancake & Waffle Mix (Paleo...       $48
# 4     Bosch 1"x 10" SDS-plus Bulldog Rotary Hammer B...       $48
# ...                                                 ...       ...
# 1346              14K Gold 30mm Thick High Polish Hoops    $84.79
# 1347  New Genie 13" Acrylic Hookah Combo Set from Pr...       $34
# ...

# %%
all_data = all_data.reset_index(drop=True)
all_data
# Out:
#                                                    Item Old Price  \
# 0     12oz Birch Benders Pancake & Waffle Mix (Paleo...       $48
# 1     12oz Birch Benders Pancake & Waffle Mix (Paleo...       $48
# 2     12oz Birch Benders Pancake & Waffle Mix (Paleo...       $48
# 3     12oz Birch Benders Pancake & Waffle Mix (Paleo...       $48
# 4     Bosch 1"x 10" SDS-plus Bulldog Rotary Hammer B...       $48
# ...                                                 ...       ...
# 7462              14K Gold 30mm Thick High Polish Hoops    $84.79
# 7463  New Genie 13" Acrylic Hookah Combo Set from Pr...       $34
# 7464  New Genie 13" Acrylic Hookah Combo Set from Pr...       $34
# 7465              Professor Morty Rolling Set (3-Piece)    $79.99
# 7466              Professor Morty Rolling Set (3-Piece)    $79.99
#
#      Pick Up Notes                                         Sale Price  \
# 0              NaN                                              $3.75
# ...

# %%
master_list = all_data

# %%
# Adding percentage change to dataframe
all_data["Percentage Change"] =

# %%
for

# %%
all_data.to_csv('1all_sale_items.csv', index=True)
